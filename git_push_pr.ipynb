# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/지하철이용 인원 변화분석/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/지하철이용 인원 변화분석

# %%
# !git config --global user.email shin970421@gmail.com
# !git config --global user.name Shin heejun

# %%
# !echo "# Seoul_Subway_dataset_practice" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://Shj-A: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@github.com/Shj-A/Seoul_Subway_dataset_practice.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Colab Notebooks/지하철이용 인원 변화분석/.git/
# [main 98a3943] first commit
#  1 file changed, 1 insertion(+)
# Counting objects: 21, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (14/14), done.
# Writing objects: 100% (21/21), 1.48 KiB | 126.00 KiB/s, done.
# Total 21 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), done.
# To https://github.com/Shj-A/Seoul_Subway_dataset_practice.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git remote rm origin

# %%
# !git add .
